# %% [markdown]
# # Worksheet 18
#
# Name: Minh Le
#
# UID: U18511806
#
# ### Topics
#
# - Linear Regression
#
# ### Optional Challenge
#
# Every day my alarm goes off at seemingly random times… I’ve recorded the times at which it goes off for the past year of so (1 - 355 days). Today is day 356. Can you predict when my alarm will ring using `data.csv`?
#
# Please fill out the piazza poll if you think you found the answer.

# %%
import pandas as pd

df = pd.read_csv("data.csv")


def process(df):
    # convert df['alarm (%H:%M:%S)] to df[H], df[M], df[S]
    df["H"] = df["alarm (%H:%M:%S)"].str.split(":").str[0]
    df["M"] = df["alarm (%H:%M:%S)"].str.split(":").str[1]
    df["S"] = df["alarm (%H:%M:%S)"].str.split(":").str[2]

    # convert to integer
    df["H"] = df["H"].astype(int)
    df["M"] = df["M"].astype(int)
    df["S"] = df["S"].astype(int)

    return df


df = process(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 355 entries, 0 to 354
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   day               355 non-null    int64
#  1   alarm (%H:%M:%S)  355 non-null    object
#  2   H                 355 non-null    int32
#  3   M                 355 non-null    int32
#  4   S                 355 non-null    int32
# dtypes: int32(3), int64(1), object(1)
# memory usage: 9.8+ KB

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(df[["day"]], df[["H", "M", "S"]])
# predict
y_pred = model.predict([[356]])
y_pred
# Out:
# c:\Users\minhl\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[20.36237766, 30.47767964, 31.44721891]])

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

axes[0].scatter(df["day"], df["H"])
axes[0].plot(df["day"], model.predict(df[["day"]])[:, 0], color="red")
axes[0].set_title("Predicted Hour")
axes[0].set_xlabel("Day")
axes[0].set_ylabel("Hour")

axes[1].scatter(df["day"], df["M"])
axes[1].plot(df["day"], model.predict(df[["day"]])[:, 1], color="red")
axes[1].set_title("Predicted Minute")
axes[1].set_xlabel("Day")
axes[1].set_ylabel("Minute")

axes[2].scatter(df["day"], df["S"])
axes[2].plot(df["day"], model.predict(df[["day"]])[:, 2], color="red")
axes[2].set_title("Predicted Second")
axes[2].set_xlabel("Day")
axes[2].set_ylabel("Second")
plt.show()

# %% [markdown]
# ## Linear Regression
#
# a) Create and plot a dataset of 100 (Y, X) points where `Y = 1 + 0.5 * X + eps`.

# %%
import numpy as np
import matplotlib.pyplot as plt

SAMPLE_SIZE = 100

true_beta = np.array([1, 0.5])  # intercept and slope
x = -10.0 + 20.0 * np.random.random(SAMPLE_SIZE)  # generate random x in [-10,10]
y = true_beta[0] + true_beta[1] * x + np.random.randn(SAMPLE_SIZE)
plt.plot(x, y, "ro", markersize=4)
plt.show()

# %% [markdown]
# b) Plot the least squares estimate line through the scatter plot.

# %%
intercept = np.ones(np.shape(x)[0])
X = np.array([intercept, x]).T
beta_hat = np.linalg.inv(X.T @ X) @ X.T @ y

x_plot = np.linspace(-10, 10, 50)
y_est = beta_hat[0] + beta_hat[1] * x_plot
plt.plot(x_plot, y_est, "b--", lw=2, label="Estimate")
plt.plot(x_plot, true_beta[0] + true_beta[1] * x_plot, lw=2, c="g", label="Truth")
plt.plot(x, y, "ro", markersize=4)
plt.legend()
plt.show()

# %% [markdown]
# c) How does the estimate of `beta` compare to the parameters we used to generate the data?

# %% [markdown]
# The estimate of beta is pretty close to the true values.

# %% [markdown]
# d) Create and plot a dataset of 100 (Y, X) points where `Y = 1 + 3 * X + .5 * X^2 + eps`.

# %%
true_beta = np.array([1, 3, 0.5])  # intercept and slope
x = -10.0 + 20.0 * np.random.random(SAMPLE_SIZE)
y = (
    true_beta[0]
    + true_beta[1] * x
    + true_beta[2] * x**2
    + np.random.randn(SAMPLE_SIZE)
)
plt.plot(x, y, "ro", markersize=4)
plt.show()

# %% [markdown]
# e) Plot the least squares estimate line through the scatter plot.

# %%
intercept = np.ones(np.shape(x)[0])
X = np.array([intercept, x, x**2]).T
beta_hat = np.linalg.inv(X.T @ X) @ X.T @ y

x_plot = np.linspace(-10, 10, 50)
y_est = beta_hat[0] + beta_hat[1] * x_plot + beta_hat[2] * x_plot**2
plt.plot(x_plot, y_est, "b--", lw=2, label="Estimate")
plt.plot(
    x_plot,
    true_beta[0] + true_beta[1] * x_plot + true_beta[2] * x_plot**2,
    lw=2,
    c="g",
    label="Truth",
)
plt.plot(x, y, "ro", markersize=4)
plt.legend()
plt.show()

# %% [markdown]
# f) How does the estimate of `beta` compare to the parameters we used to generate the data?

# %% [markdown]
# The estimate of beta is close to the true value.

# %% [markdown]
# g) Let's repeat d) and f) a large number of times to see how close our estimates are on average and what that distribution looks like.

# %%
import numpy as np
import matplotlib.pyplot as plt

betas = []
true_beta = np.array([1, 3, 0.5])

for _ in range(10000):
    x = -1 + 2 * np.random.random(SAMPLE_SIZE)
    y = (
        true_beta[0]
        + true_beta[1] * x
        + true_beta[2] * x**2
        + np.random.randn(SAMPLE_SIZE)
    )
    xlin = x
    intercept = np.ones(np.shape(xlin)[0])
    X = np.array([intercept, xlin]).T
    betas.append(np.linalg.inv(X.T @ X) @ X.T @ y)

plt.hist(np.array(betas)[:, 1], bins=100)
plt.axvline(x=true_beta[1], c="r", linestyle="dashed")
plt.show()
